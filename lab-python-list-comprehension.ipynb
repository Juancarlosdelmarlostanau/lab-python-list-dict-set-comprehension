# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %% [markdown]
# # Formulas
#
# ### **for** -> new_list = [operation for elem in original_list]
#
# ### **+if** -> new_list = [operation for elem in original_list if condition is True]
#
# ### **+else** -> new_list = [operation1 if condition is True else operation2 for element in original_list]

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# %% [markdown]
# 1.Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.

# %% [markdown]
# - Usando funciones:

# %%
def initialize_inventory(products):
    inventory = {}
    for p in products:
        inventory[p] = int(input(f"que cantidad de productos hay?:"))
    return inventory

initialize_inventory(products)

# %% [markdown]
# - Usando comprehension

# %%
inventory = {p:int(input(f"que cantidad de productos hay?:")) for p in products}
inventory
# Out:
# {'t-shirt': 5, 'mug': 4, 'hat': 3, 'book': 2, 'keychain': 1}

# %% [markdown]
# 2. Modifique la función get_customer_orders para que solicite al usuario que ingrese el número de pedidos de los clientes
#  y recopile los nombres de los productos mediante un bucle y la entrada del usuario. Utilice la comprensión.

# %% [markdown]
# - Usando solo funcione:

# %%
def get_customer_orders():
    num_orders = int(input(f"ingrese cantidad de pedidos"))
    customer_orders = []

    for pedido in range(num_orders):
        pedido = input(f"ingrese una opcion de entre : t-shirt, mug, hat, book, or keychain").lower()
        customer_orders.append(pedido)
    return customer_orders
customer_orders = get_customer_orders()
customer_orders

# %% [markdown]
# - Usando comprehension

# %%
num_orders = int(input(f"ingrese cantidad de pedidos"))
def get_customer_orders():
    customer_orders = [input(f"ingrese una opcion de entre : t-shirt, mug, hat, book, or keychain").lower() for pedido in range(num_orders)]
    return customer_orders

customer_orders = get_customer_orders()
customer_orders

# %%
num_orders = int(input(f"ingrese cantidad de pedidos"))
customer_orders = [input(f"ingrese una opcion de entre : t-shirt, mug, hat, book, or keychain").lower() for pedido in range(num_orders)]
print(num_orders)
print(customer_orders)
# Out:
# 2
# ['hat', 'keychain']

# %% [markdown]
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.

# %% [markdown]
# - Usando funciones:

# %%
def calculate_total_price(customer_orders):
    precio_unitario = []
    total_price = []
    for producto in customer_orders:
        precio = int(input(f"precio del producto: {producto}"))
        precio_unitario.append(precio)

    total_price = sum(precio_unitario)
    return total_price

total_price = calculate_total_price(customer_orders)
total_price

# %% [markdown]
# - Usando comprehension

# %%
total_price = sum([int(input(f"precio del producto {producto}:")) for producto in customer_orders])
total_price
# Out:
# 15

# %% [markdown]
# - Usando funciones:

# %%
def calculate_order_statistics(customer_orders,products):
    order_statistics = []

    total_products_ordered = len(customer_orders)
    percentage_ordered = (len(customer_orders) / len(products)) * 100
    order_statistics = total_products_ordered,f"{percentage_ordered} %"
    return order_statistics

# %% [markdown]
# - Usando comprehension

# %%
orders_statistics = [len(customer_orders), f"{(len(customer_orders) / len(products)) * 100} %"]
orders_statistics
# Out:
# [2, '40.0 %']

# %% [markdown]
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.

# %% [markdown]
# - Usando funciones:

# %%
def update_inventory(customer_orders, inventory):
    for x in customer_orders:
        if x in inventory:
            inventory[x] -= 1
    updated = {}
    for a, b in inventory.items():
        if b > 0:
           updated[a] = b
    return updated

resultado = update_inventory(customer_orders, inventory)
print(resultado)

# %% [markdown]
# - Usando comprehension

# %%
def update_inventory(customer_orders, inventory):
    for x in customer_orders:
        if x in inventory:
            inventory[x] -= 1

    update_inventory = {a: b for a, b in inventory.items() if b > 0}
    return update_inventory

resultado = update_inventory(customer_orders, inventory)
print(resultado)
# Out:
# {'t-shirt': 5, 'mug': 4, 'hat': 2, 'book': 2}

# %% [markdown]
# 5. Print the total price of the customer order.

# %%
print(total_price)
# Out:
# 15
